# %%
import pandas as pd
import numpy as np

# %% [markdown]
# Pandas est une librairie qui permet de manipuler les labels(index) d'un ensemble de données avec des structrures données:
# - Series (Pour les structures à 1 dimension)
# - DataFrame (Pour les structures à 2 dimensions
#
# Pandas supporte de grande variété de format de données à l'importation et à l'exportation tels que: CSV, SQL, Json, Excel, Html, Python, ...

# %% [markdown]
# ## Création d'une Series avec `np.Series()`

# %% [markdown]
# Une `Series` a une certaine similarité avec un dictionnaire python

# %%
S = pd.Series([x**2 for x in range(10)])
S
# Out:
# 0     0
# 1     1
# 2     4
# 3     9
# 4    16
# 5    25
# 6    36
# 7    49
# 8    64
# 9    81
# dtype: int64

# %%
S = pd.Series([x**2 for x in range(10)], dtype='int8')
S
# Out:
# 0     0
# 1     1
# 2     4
# 3     9
# 4    16
# 5    25
# 6    36
# 7    49
# 8    64
# 9    81
# dtype: int8

# %%
S = pd.Series(data=[x**2 for x in range(10)],
              index=[x for x in 'abcdefghij'],
              dtype='int8')
S
# Out:
# a     0
# b     1
# c     4
# d     9
# e    16
# f    25
# g    36
# h    49
# i    64
# j    81
# dtype: int8

# %% [markdown]
# - Avec un dictionnaire

# %%
d = {k: v**2 for k, v in zip('abcdefghij', range(10))}
print(d)
# Out:
# {'a': 0, 'b': 1, 'c': 4, 'd': 9, 'e': 16, 'f': 25, 'g': 36, 'h': 49, 'i': 64, 'j': 81}

# %%
S = pd.Series(d, dtype='int8')
S
# Out:
# a     0
# b     1
# c     4
# d     9
# e    16
# f    25
# g    36
# h    49
# i    64
# j    81
# dtype: int8

# %%
print(S['f'])
# Out:
# 25

# %%
print(S.loc['f'])
# Out:
# 25

# %% [markdown]
# L’index d’une Series est un objet implémenté sous la forme d’un ndarray de numpy, mais qui ne peut contenir que des objets hashables (pour garantir la performance de l’accès).

# %%
print(S.index)
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], dtype='str')

# %% [markdown]
# Les valeurs d'une Series sont accessibles avec l'attribut `values`qui renvoie un objet ndarray

# %%
print(S.values)
# Out:
# [ 0  1  4  9 16 25 36 49 64 81]

# %% [markdown]
# Mais une Series a également une interface de dictionnaire à laquelle on accède de la manière suivante:

# %%
S.keys()
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h', 'i', 'j'], dtype='str')

# %%
for k, v in S.items():
    print(k, v)
# Out:
# a 0
# b 1
# c 4
# d 9
# e 16
# f 25
# g 36
# h 49
# i 64
# j 81

# %% [markdown]
# Le test d'appartenance est possible sur les index

# %%
'a' in S, 'z' in S
# Out:
# (True, False)

# %% [markdown]
# Il est possible de modifier ou d'avoir des données de différents types dans un dataframe.

# %%
S = pd.Series(range(10_000))
S
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 9995    9995
# 9996    9996
# 9997    9997
# 9998    9998
# 9999    9999
# Length: 10000, dtype: int64

# %%
S.values.dtype
# Out:
# dtype('int64')

# %%
# %timeit S**2
# Out:
# 60.3 μs ± 2.77 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
S[10_000] = 'spam'
S
# Out:
# 0           0
# 1           1
# 2           2
# 3           3
# 4           4
#          ...
# 9996     9996
# 9997     9997
# 9998     9998
# 9999     9999
# 10000    spam
# Length: 10001, dtype: object

# %%
del S[10_000]

# %%
S
# Out:
# 0          0
# 1          1
# 2          2
# 3          3
# 4          4
#         ...
# 9995    9995
# 9996    9996
# 9997    9997
# 9998    9998
# 9999    9999
# Length: 10000, dtype: object

# %%
# %timeit S**2
# Out:
# 462 μs ± 27.6 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
S.values.dtype
# Out:
# dtype('O')

# %%
print(S.values.dtype)
# Out:
# object

# %% [markdown]
# Maintenant, les opérations vectorisées le sont sur des objets Python et non plus sur des int64, il y a donc un impact sur la performance.

# %%
S = pd.Series([1, 2, 3])
S
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
S[3] = '4'
S
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: object

# %% [markdown]
# Les entiers sont additionnés, mais les chaînes de caractères concaténées.

# %%
S + S
# Out:
# 0     2
# 1     4
# 2     6
# 3    44
# dtype: object

# %% [markdown]
# - Avec des index de type `str`

# %%
s = pd.Series([20, 30, 40, 50],
              index=['eve', 'bill', 'liz', 'bob'])

# %%
s
# Out:
# eve     20
# bill    30
# liz     40
# bob     50
# dtype: int64

# %% [markdown]
# Accéder aux valeurs d'une Series

# %%
s.values
# Out:
# array([20, 30, 40, 50])

# %% [markdown]
# Accéder aux index d'une Series

# %%
s.index
# Out:
# Index(['eve', 'bill', 'liz', 'bob'], dtype='str')

# %% [markdown]
# Cette notation `s['eve']` doit être évité à cause des effets de bords

# %%
s.loc['eve']
# Out:
# np.int64(20)

# %% [markdown]
# Le slicing sur les `series` inclut les 2 éléments de l'intervalle

# %%
s.loc['eve': 'liz']
# Out:
# eve     20
# bill    30
# liz     40
# dtype: int64

# %%
s = pd.Series([20, 30, 40, 50],
              index=['eve', 'liz', 'bill', 'bob'])

# %%
s.loc['eve': 'liz']
# Out:
# eve    20
# liz    30
# dtype: int64

# %% [markdown]
# Le slicing sur les labels ne fonctionne pas s'ils sont dubliqués et ne sont pas triés

# %%
animaux = ['chien', 'chat', 'chat', 'chien', 'poisson']
proprio = ['eve', 'bob', 'eve', 'bill', 'liz']

# %%
s = pd.Series(animaux, index=proprio)
s
# Out:
# eve       chien
# bob        chat
# eve        chat
# bill      chien
# liz     poisson
# dtype: str

# %%
# Ceci lancera une erreur
# s.loc['eve': 'liz']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[140], line 2
#       1 # Ceci lancera une erreur
# ----> 2 s.loc['eve': 'liz']
#
# File /Users/Chris/Engineering/Computer Science/Learning/Data science/.venv/lib/python3.14/site-packages/pandas/core/indexing.py:1207, in _LocationIndexer.__getitem__(self, key)
#    1205 maybe_callable = com.apply_if_callable(key, self.obj)
#    1206 maybe_callable = self._raise_callable_usage(key, maybe_callable)
# -> 1207 return self._getitem_axis(maybe_callable, axis=axis)
#
# File /Users/Chris/Engineering/Computer Science/Learning/Data science/.venv/lib/python3.14/site-packages/pandas/core/indexing.py:1429, in _LocIndexer._getitem_axis(self, key, axis)
#    1427 if isinstance(key, slice):
#    1428     self._validate_key(key, axis)
# -> 1429     return self._get_slice_axis(key, axis=axis)
#    1430 elif com.is_bool_indexer(key):
#    1431     return self._getbool_axis(key, axis=axis)
#
# File /Users/Chris/Engineering/Computer Science/Learning/Data science/.venv/lib/python3.14/site-packages/pandas/core/indexing.py:1461, in _LocIndexer._get_slice_axis(self, slice_obj, axis)
#    1458     return obj.copy(deep=False)
#    1460 labels = obj._get_axis(axis)
# -> 1461 indexer = labels.slice_indexer(slice_obj.start, slice_obj.stop, slice_obj.step)
#    1463 if isinstance(indexer, slice):
#    1464     return self.obj._slice(indexer, axis=axis)
#
# File /Users/Chris/Engineering/Computer Science/Learning/Data science/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:6804, in Index.slice_indexer(self, start, end, step)
#    6753 def slice_indexer(
#    6754     self,
#    6755     start: Hashable | None = None,
#    6756     end: Hashable | None = None,
#    6757     step: int | None = None,
#    6758 ) -> slice:
#    6759     """
#    6760     Compute the slice indexer for input labels and step.
#    6761
#    (...)   6802     slice(1, 3, None)
#    6803     """
# -> 6804     start_slice, end_slice = self.slice_locs(start, end, step=step)
#    6806     # return a slice
#    6807     if not is_scalar(start_slice):
#
# File /Users/Chris/Engineering/Computer Science/Learning/Data science/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:7062, in Index.slice_locs(self, start, end, step)
#    7060 start_slice = None
#    7061 if start is not None:
# -> 7062     start_slice = self.get_slice_bound(start, "left")
#    7063 if start_slice is None:
#    7064     start_slice = 0
#
# File /Users/Chris/Engineering/Computer Science/Learning/Data science/.venv/lib/python3.14/site-packages/pandas/core/indexes/base.py:6985, in Index.get_slice_bound(self, label, side)
#    6983     slc = lib.maybe_booleans_to_slice(slc.view("u1"))
#    6984     if isinstance(slc, np.ndarray):
# -> 6985         raise KeyError(
#    6986             f"Cannot get {side} slice bound for non-unique "
#    6987             f"label: {original_label!r}"
#    6988         )
#    6990 if isinstance(slc, slice):
#    6991     if side == "left":
#
# KeyError: "Cannot get left slice bound for non-unique label: 'eve'"

# %%
s = s.sort_index()
s

# %%
s.loc['eve': 'liz']

# %%
s.iloc[0]

# %%
s.iloc[4]

# %%
s.iloc[1:3]

# %%
s=='chien'

# %%
s.loc[(s=='chien')]

# %%
s.loc[(s=='chien') | (s=='poisson')]

# %%
s.loc[~((s=='chien') | (s=='poisson'))] = 'autre'
s

# %%
s1 = pd.Series([1, 2, 3], index=list('abc'))

# %%
s2 = pd.Series([5, 6, 7], index=list('acd'))

# %%
s1

# %%
s2

# %% [markdown]
# L'opération n'est défini que pour les entités ayant le même label

# %%
s1 + s2

# %%
s1.add(s2)

# %%
s1.add(s2, fill_value=50)
