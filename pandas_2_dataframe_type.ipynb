# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ## Création d'un DataFrame

# %%
age = pd.Series([30, 20, 50], index=['alice', 'bob', 'julie'])

# %%
height = pd.Series([150, 170, 168], index=['alice', 'marc', 'julie'])

# %% [markdown]
# - `Pandas` fait automatiquement l'alignement des index

# %%
stat = pd.DataFrame({'age': age, 'height': height})

# %%
stat
# Out:
#         age  height
# alice  30.0   150.0
# bob    20.0     NaN
# julie  50.0   168.0
# marc    NaN   170.0

# %% [markdown]
# - Broadcasting d'une valeur de colonne sur toutes les lignes

# %%
stat = pd.DataFrame({'age': age, 'height': height, 'city': 'Nice'})
print(stat)
# Out:
#         age  height  city
# alice  30.0   150.0  Nice
# bob    20.0     NaN  Nice
# julie  50.0   168.0  Nice
# marc    NaN   170.0  Nice

# %%
print(stat.index)
# Out:
# Index(['alice', 'bob', 'julie', 'marc'], dtype='object')

# %%
print(stat.columns)
# Out:
# Index(['age', 'height', 'city'], dtype='object')

# %%
print(stat.values)
# Out:
# [[30.0 150.0 'Nice']
#  [20.0 nan 'Nice']
#  [50.0 168.0 'Nice']
#  [nan 170.0 'Nice']]

# %% [markdown]
# - Accéder aux données d'un DataFrame

# %%
a = stat.loc['alice', 'age']

# %%
type(a)
# Out:
# numpy.float64

# %%
print(a)
# Out:
# 30.0

# %%
c = stat.loc[:, 'age']
m = c.mean()
print(f"L'âge moyen est de {m:.1f} ans.")
# Out:
# L'âge moyen est de 33.3 ans.

# %%
type(c)
# Out:
# pandas.core.series.Series

# %%
type(m)
# Out:
# numpy.float64

# %%
a = np.random.randint(1, 20, 9).reshape(3, 3)
p = pd.DataFrame(a, index=['a', 'b', 'c'], columns=['x', 'y', 'z'])

# %%
print(a)
# Out:
# [[11 11 10]
#  [13  9  7]
#  [13  1  9]]

# %%
p
# Out:
#     x   y   z
# a  11  11  10
# b  13   9   7
# c  13   1   9

# %%
print(p)
# Out:
#     x   y   z
# a  11  11  10
# b  13   9   7
# c  13   1   9

# %%
prenoms = ['liz', 'bob', 'bill', 'eve']

# %%
age = pd.Series([25, 30, 35, 40], index=prenoms)

# %%
taille = pd.Series([160, 175, 170, 180], index=prenoms)

# %%
sexe = pd.Series(list("fhhf"), index=prenoms)

# %%
df = pd.DataFrame(
    {
        'age': age,
        'taille': taille,
        'sexe': sexe
    },
)

# %%
df
# Out:
#       age  taille sexe
# liz    25     160    f
# bob    30     175    h
# bill   35     170    h
# eve    40     180    f

# %%
df.index
# Out:
# Index(['liz', 'bob', 'bill', 'eve'], dtype='object')

# %%
df.columns
# Out:
# Index(['age', 'taille', 'sexe'], dtype='object')

# %%
df.values
# Out:
# array([[25, 160, 'f'],
#        [30, 175, 'h'],
#        [35, 170, 'h'],
#        [40, 180, 'f']], dtype=object)

# %%
df.head(2)
# Out:
#      age  taille sexe
# liz   25     160    f
# bob   30     175    h

# %%
df.tail(2)
# Out:
#       age  taille sexe
# bill   35     170    h
# eve    40     180    f

# %%
df.describe()
# Out:
#              age      taille
# count   4.000000    4.000000
# mean   32.500000  171.250000
# std     6.454972    8.539126
# min    25.000000  160.000000
# 25%    28.750000  167.500000
# 50%    32.500000  172.500000
# 75%    36.250000  176.250000
# max    40.000000  180.000000

# %% [markdown]
# ### Indexation de ligne

# %%
df.loc['liz']
# Out:
# age        25
# taille    160
# sexe        f
# Name: liz, dtype: object

# %% [markdown]
# ### Indexation de cellule ou d'observation

# %%
print(df.loc['liz', 'age'])
# Out:
# 25

# %% [markdown]
# ### Indexation d'un sous ensemble de DataFrame

# %%
df.loc[:, 'taille']
# Out:
# liz     160
# bob     175
# bill    170
# eve     180
# Name: taille, dtype: int64

# %% [markdown]
# ### Application d'un masque et broadcasting

# %%
df.loc[df.loc[:, 'age']<32]
# Out:
#      age  taille sexe
# liz   25     160    f
# bob   30     175    h

# %% [markdown]
# ### Transformation d'un index ligne en index de colonne

# %%
df = df.reset_index()
df
# Out:
#   index  age  taille sexe
# 0   liz   25     160    f
# 1   bob   30     175    h
# 2  bill   35     170    h
# 3   eve   40     180    f

# %% [markdown]
# ### Renommer des index de colonne

# %%
df = df.rename(columns={'index': 'prenom'})
df
# Out:
#   prenom  age  taille sexe
# 0    liz   25     160    f
# 1    bob   30     175    h
# 2   bill   35     170    h
# 3    eve   40     180    f

# %% [markdown]
# ### Redéfinir un index de colonne en tant qu'index de ligne

# %%
df = df.set_index('age')
df
# Out:
#     prenom  taille sexe
# age
# 25     liz     160    f
# 30     bob     175    h
# 35    bill     170    h
# 40     eve     180    f

# %% [markdown]
# ## Approche moderne

# %%
df = pd.DataFrame(
    {
        'age': age,
        'taille': taille,
        'sexe': sexe
    },
)

# %%
df
# Out:
#       age  taille sexe
# liz    25     160    f
# bob    30     175    h
# bill   35     170    h
# eve    40     180    f

# %%
df = (
    df.reset_index()
    .rename(columns={'index':'prenoms'})
    .set_index('age')
)

# %%
df
# Out:
#     prenoms  taille sexe
# age
# 25      liz     160    f
# 30      bob     175    h
# 35     bill     170    h
# 40      eve     180    f

# %% [markdown]
# ## Résolution d'alignement d'index

# %%
df1 = pd.DataFrame(np.ones((2, 2), dtype=np.int8),
                   index=list('ab'),
                   columns=list('xy')
                   )

# %%
df1
# Out:
#    x  y
# a  1  1
# b  1  1

# %%
df2 = pd.DataFrame(np.ones((2, 2), dtype=np.int8),
                   index=list('ac'),
                   columns=list('xz')
                   )

# %%
df2
# Out:
#    x  z
# a  1  1
# c  1  1

# %%
df1 + df2
# Out:
#      x   y   z
# a  2.0 NaN NaN
# b  NaN NaN NaN
# c  NaN NaN NaN

# %% [markdown]
# - `fill_value` ne fonctionne que s'il manque une valeur à gauche ou à droite (pas si les deux sont absents)

# %%
df1.add(df2, fill_value=0)
# Out:
#      x    y    z
# a  2.0  1.0  1.0
# b  1.0  1.0  NaN
# c  1.0  NaN  1.0

# %%
df = df1.add(df2, fill_value=0)
df
# Out:
#      x    y    z
# a  2.0  1.0  1.0
# b  1.0  1.0  NaN
# c  1.0  NaN  1.0

# %% [markdown]
# - Remplacer les valeur `NaN` par une autre valeur

# %%
df.fillna(-1)
# Out:
#      x    y    z
# a  2.0  1.0  1.0
# b  1.0  1.0 -1.0
# c  1.0 -1.0  1.0

# %% [markdown]
# - Retirer les lignes contenant des valeurs `NaN`

# %%
df.dropna()
# Out:
#      x    y    z
# a  2.0  1.0  1.0

# %% [markdown]
# ## Importation et exportation de données

# %% [markdown]
# ### Exportation

# %%
p
# Out:
#     x   y   z
# a  11  11  10
# b  13   9   7
# c  13   1   9

# %%
p.to_csv('data/data.csv')

# %%
# !cat data/data.csv
# Out:
# ,x,y,z
# a,11,11,10
# b,13,9,7
# c,13,1,9

# %%
p.to_json('data/data.json')

# %%
# !cat data/data.json
# Out:
# {"x":{"a":11,"b":13,"c":13},"y":{"a":11,"b":9,"c":1},"z":{"a":10,"b":7,"c":9}}

# %% [markdown]
# ### Importation

# %%
new_p = pd.read_json('data/data.json')
new_p
# Out:
#     x   y   z
# a  11  11  10
# b  13   9   7
# c  13   1   9

# %%
new_p = pd.read_csv('data/data.csv')
new_p
# Out:
#   Unnamed: 0   x   y   z
# 0          a  11  11  10
# 1          b  13   9   7
# 2          c  13   1   9

# %% [markdown]
# ## Manipulation d'une DataFrame

# %%
names = ['alice', 'bob', 'marc', 'bill', 'sonia']

age = pd.Series([12, 13, 16, 11, 16], index=names)
height = pd.Series([130, 140, 176, 120, 165], index=names)
sex = pd.Series(list('fmmmf'), index=names)

p = pd.DataFrame({'age': age, 'height': height, 'sex': sex})
print(p)
# Out:
#        age  height sex
# alice   12     130   f
# bob     13     140   m
# marc    16     176   m
# bill    11     120   m
# sonia   16     165   f

# %%
import seaborn as sns

tips = sns.load_dataset('tips')

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.tail()
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2

# %%
tips.index
# Out:
# RangeIndex(start=0, stop=244, step=1)

# %%
p.index
# Out:
# Index(['alice', 'bob', 'marc', 'bill', 'sonia'], dtype='object')

# %%
tips.values
# Out:
# array([[16.99, 1.01, 'Female', ..., 'Sun', 'Dinner', 2],
#        [10.34, 1.66, 'Male', ..., 'Sun', 'Dinner', 3],
#        [21.01, 3.5, 'Male', ..., 'Sun', 'Dinner', 3],
#        ...,
#        [22.67, 2.0, 'Male', ..., 'Sat', 'Dinner', 2],
#        [17.82, 1.75, 'Male', ..., 'Sat', 'Dinner', 2],
#        [18.78, 3.0, 'Female', ..., 'Thur', 'Dinner', 2]],
#       shape=(244, 7), dtype=object)

# %%
p.values
# Out:
# array([[12, 130, 'f'],
#        [13, 140, 'm'],
#        [16, 176, 'm'],
#        [11, 120, 'm'],
#        [16, 165, 'f']], dtype=object)

# %%
tips.keys()
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
p.keys()
# Out:
# Index(['age', 'height', 'sex'], dtype='object')

# %%
tips.columns
# Out:
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')

# %%
p.columns
# Out:
# Index(['age', 'height', 'sex'], dtype='object')

# %%
tips.items()
# Out:
# <generator object DataFrame.items at 0x130498240>

# %%
p.items()
# Out:
# <generator object DataFrame.items at 0x130498340>

# %%
tips.transpose()
# Out:
#                0       1       2       3       4       5       6       7    \
# total_bill   16.99   10.34   21.01   23.68   24.59   25.29    8.77   26.88
# tip           1.01    1.66     3.5    3.31    3.61    4.71     2.0    3.12
# sex         Female    Male    Male    Male  Female    Male    Male    Male
# smoker          No      No      No      No      No      No      No      No
# day            Sun     Sun     Sun     Sun     Sun     Sun     Sun     Sun
# time        Dinner  Dinner  Dinner  Dinner  Dinner  Dinner  Dinner  Dinner
# size             2       3       3       2       4       4       2       4
#
#                8       9    ...     234     235     236     237     238  \
# total_bill   15.04   14.78  ...   15.53   10.07    12.6   32.83   35.83
# tip           1.96    3.23  ...     3.0    1.25     1.0    1.17    4.67
# sex           Male    Male  ...    Male    Male    Male    Male  Female
# smoker          No      No  ...     Yes      No     Yes     Yes      No
# day            Sun     Sun  ...     Sat     Sat     Sat     Sat     Sat
# time        Dinner  Dinner  ...  Dinner  Dinner  Dinner  Dinner  Dinner
# size             2       2  ...       2       2       2       2       3
#
#                239     240     241     242     243
# total_bill   29.03   27.18   22.67   17.82   18.78
# tip           5.92     2.0     2.0    1.75     3.0
# sex           Male  Female    Male    Male  Female
# smoker          No     Yes     Yes      No      No
# day            Sat     Sat     Sat     Sat    Thur
# time        Dinner  Dinner  Dinner  Dinner  Dinner
# size             3       2       2       2       2
#
# [7 rows x 244 columns]

# %%
p.T
# Out:
#        alice  bob marc bill sonia
# age       12   13   16   11    16
# height   130  140  176  120   165
# sex        f    m    m    m     f

# %% [markdown]
# - Obtenir les premières statistiques avec `describe()` sur des types numériques

# %%
tips.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
p.describe()
# Out:
#              age      height
# count   5.000000    5.000000
# mean   13.600000  146.200000
# std     2.302173   23.605084
# min    11.000000  120.000000
# 25%    12.000000  130.000000
# 50%    13.000000  140.000000
# 75%    16.000000  165.000000
# max    16.000000  176.000000

# %% [markdown]
# - Obtenir des statistiques sur des types numériques et de chaînes de caractères

# %%
tips.describe(include='all')
# Out:
#         total_bill         tip   sex smoker  day    time        size
# count   244.000000  244.000000   244    244  244     244  244.000000
# unique         NaN         NaN     2      2    4       2         NaN
# top            NaN         NaN  Male     No  Sat  Dinner         NaN
# freq           NaN         NaN   157    151   87     176         NaN
# mean     19.785943    2.998279   NaN    NaN  NaN     NaN    2.569672
# std       8.902412    1.383638   NaN    NaN  NaN     NaN    0.951100
# min       3.070000    1.000000   NaN    NaN  NaN     NaN    1.000000
# 25%      13.347500    2.000000   NaN    NaN  NaN     NaN    2.000000
# 50%      17.795000    2.900000   NaN    NaN  NaN     NaN    2.000000
# 75%      24.127500    3.562500   NaN    NaN  NaN     NaN    3.000000
# max      50.810000   10.000000   NaN    NaN  NaN     NaN    6.000000

# %%
p.describe(include='all')
# Out:
#               age      height  sex
# count    5.000000    5.000000    5
# unique        NaN         NaN    2
# top           NaN         NaN    m
# freq          NaN         NaN    3
# mean    13.600000  146.200000  NaN
# std      2.302173   23.605084  NaN
# min     11.000000  120.000000  NaN
# 25%     12.000000  130.000000  NaN
# 50%     13.000000  140.000000  NaN
# 75%     16.000000  165.000000  NaN
# max     16.000000  176.000000  NaN

# %% [markdown]
# - Requêtes sur une DataFrame

# %%
p
# Out:
#        age  height sex
# alice   12     130   f
# bob     13     140   m
# marc    16     176   m
# bill    11     120   m
# sonia   16     165   f

# %%
p.loc['sonia']
# Out:
# age        16
# height    165
# sex         f
# Name: sonia, dtype: object

# %%
print(p.loc['sonia', 'age'])
# Out:
# 16

# %%
p.loc[:, 'sex'] == 'f'
# Out:
# alice     True
# bob      False
# marc     False
# bill     False
# sonia     True
# Name: sex, dtype: bool

# %%
p.loc[p.loc[:, 'sex'] == 'f', :]
# Out:
#        age  height sex
# alice   12     130   f
# sonia   16     165   f

# %%
p.loc[(p.loc[:, 'sex'] == 'f') & (p.loc[:, 'age'] > 14), :]
# Out:
#        age  height sex
# sonia   16     165   f

# %%
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
addition_f = tips.loc[tips.loc[:, 'sex'] == 'Female', 'total_bill'].mean()
print(f"Addition moyenne des femmes : {addition_f:.2f}€")
# Out:
# Addition moyenne des femmes : 18.06€

# %%
addition_h = tips.loc[tips.loc[:, 'sex'] == 'Male', 'total_bill'].mean()
print(f"Addition moyenne des hommes : {addition_h:.2f}€")
# Out:
# Addition moyenne des hommes : 20.74€

# %%
pourboire_f = tips.loc[tips.loc[:, 'sex'] == 'Female', 'tip'].mean()
print(pourboire_f)
# Out:
# 2.8334482758620685

# %%
pourboire_h = tips.loc[tips.loc[:, 'sex'] == 'Male', 'tip'].mean()
print(pourboire_h)
# Out:
# 3.0896178343949043

# %%
print(f"Les femmes laissent {pourboire_f/addition_f:.2%} de pourboire")
print(f"Les hommes laissent {pourboire_h/addition_h:.2%} de pourboire")
# Out:
# Les femmes laissent 15.69% de pourboire
# Les hommes laissent 14.89% de pourboire

# %%
p
# Out:
#        age  height sex
# alice   12     130   f
# bob     13     140   m
# marc    16     176   m
# bill    11     120   m
# sonia   16     165   f

# %%
p['mean'] = 1
p
# Out:
#        age  height sex  mean
# alice   12     130   f     1
# bob     13     140   m     1
# marc    16     176   m     1
# bill    11     120   m     1
# sonia   16     165   f     1

# %%
p.loc[:, 'mean']
# Out:
# alice    1
# bob      1
# marc     1
# bill     1
# sonia    1
# Name: mean, dtype: int64

# %% [markdown]
# ### `df.drop()`

# %%
pp = p.drop(columns='mean')
pp
# Out:
#        age  height sex
# alice   12     130   f
# bob     13     140   m
# marc    16     176   m
# bill    11     120   m
# sonia   16     165   f

# %%
p.drop(columns='mean', inplace=True)
print(p)
# Out:
#        age  height sex
# alice   12     130   f
# bob     13     140   m
# marc    16     176   m
# bill    11     120   m
# sonia   16     165   f

# %% [markdown]
# ## Les `ufunc` avec pandas

# %%
d = pd.DataFrame(
    np.random.randint(1, 10, 9).reshape(3, 3),
    columns=list('abc')
)

print(d)
# Out:
#    a  b  c
# 0  5  9  6
# 1  8  4  9
# 2  5  9  7

# %%
np.log(d)
# Out:
#           a         b         c
# 0  1.609438  2.197225  1.791759
# 1  2.079442  1.386294  2.197225
# 2  1.609438  2.197225  1.945910

# %% [markdown]
# - Si l’on a besoin d’alignement de labels, les ufunc de numpy ne vont pas faire ce à quoi on s’attend. Elles vont faire les opérations sur les tableaux numpy sans prendre en compte les labels. Pour avoir un alignement des labels, il faut utiliser les ufunc de pandas.

# %%
s1 = pd.Series([10, 20, 30], index=list('abc'))

print(s1)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
s2 = pd.Series([12, 22, 32], index=list('acd'))

print(s2)
# Out:
# a    12
# c    22
# d    32
# dtype: int64

# %%
np.add(s1, s2)
# Out:
# a    22.0
# b     NaN
# c    52.0
# d     NaN
# dtype: float64

# %%
s1.add(s2)
# Out:
# a    22.0
# b     NaN
# c    52.0
# d     NaN
# dtype: float64

# %%
s1.add(s2, fill_value=0)
# Out:
# a    22.0
# b    20.0
# c    52.0
# d    32.0
# dtype: float64

# %%
names = ['alice', 'bob', 'charle']

bananas = pd.Series([10, 3, 9], index=names)
oranges = pd.Series([3, 11, 6], index=names)

fruits_jan = pd.DataFrame({'bananas': bananas, 'oranges': oranges})

# %%
bananas = pd.Series([6, 1], index=names[:-1])
apples = pd.Series([8, 5], index=names[1:])

fruits_feb = pd.DataFrame({'bananas': bananas, 'apples': apples})

# %%
fruits_jan
# Out:
#         bananas  oranges
# alice        10        3
# bob           3       11
# charle        9        6

# %%
fruits_feb
# Out:
#         bananas  apples
# alice       6.0     NaN
# bob         1.0     8.0
# charle      NaN     5.0

# %%
eaten_fruits = fruits_jan + fruits_feb
eaten_fruits
# Out:
#         apples  bananas  oranges
# alice      NaN     16.0      NaN
# bob        NaN      4.0      NaN
# charle     NaN      NaN      NaN

# %% [markdown]
# - Lorsqu’une valeur est absente dans toutes les DataFrame, NaN est conservé.

# %%
eaten_fruits = fruits_jan.add(fruits_feb, fill_value=0)
eaten_fruits
# Out:
#         apples  bananas  oranges
# alice      NaN     16.0      3.0
# bob        8.0      4.0     11.0
# charle     5.0      9.0      6.0

# %%
eaten_fruits.fillna(0)
# Out:
#         apples  bananas  oranges
# alice      0.0     16.0      3.0
# bob        8.0      4.0     11.0
# charle     5.0      9.0      6.0

# %%
eaten_fruits.dropna()
# Out:
#         apples  bananas  oranges
# bob        8.0      4.0     11.0
# charle     5.0      9.0      6.0

# %%
eaten_fruits
# Out:
#         apples  bananas  oranges
# alice      NaN     16.0      3.0
# bob        8.0      4.0     11.0
# charle     5.0      9.0      6.0

# %%
data_frame = pd.DataFrame(
    np.random.randint(1, 10, size=(3, 3)),
    columns=list('abc'),
    index=list('xyz')
)

data_frame
# Out:
#    a  b  c
# x  3  4  8
# y  6  9  9
# z  2  2  8

# %%
series_row = pd.Series(
    [100, 200, 300],
    index=list('abc')
)

series_row
# Out:
# a    100
# b    200
# c    300
# dtype: int64

# %%
series_col = pd.Series(
    [400, 500, 600],
    index=list('xyz')
)

series_col
# Out:
# x    400
# y    500
# z    600
# dtype: int64

# %%
data_frame + series_row
# Out:
#      a    b    c
# x  103  204  308
# y  106  209  309
# z  102  202  308

# %%
data_frame + series_col
# Out:
#     a   b   c   x   y   z
# x NaN NaN NaN NaN NaN NaN
# y NaN NaN NaN NaN NaN NaN
# z NaN NaN NaN NaN NaN NaN

# %%
data_frame.add(series_col, axis=0)
# Out:
#      a    b    c
# x  403  404  408
# y  506  509  509
# z  602  602  608

# %% [markdown]
# ## Opérations sur les chaînes de caractères

# %%
names = ['alice', ' bOB', 'Marc', 'bill', 3, ' JULIE ', np.nan]
age = pd.Series(names)

print(age)
# Out:
# 0      alice
# 1        bOB
# 2       Marc
# 3       bill
# 4          3
# 5     JULIE
# 6        NaN
# dtype: object

# %% [markdown]
# - Nettoyage de données

# %%
a = age.str.lower()
a = a.str.strip()
a
# Out:
# 0    alice
# 1      bob
# 2     marc
# 3     bill
# 4      NaN
# 5    julie
# 6      NaN
# dtype: object

# %%
[x for x in age.str.lower().str.strip()]
# Out:
# ['alice', 'bob', 'marc', 'bill', nan, 'julie', nan]

# %%
print(a)
# Out:
# 0    alice
# 1      bob
# 2     marc
# 3     bill
# 4      NaN
# 5    julie
# 6      NaN
# dtype: object

# %%
print(a.str[-1])
# Out:
# 0      e
# 1      b
# 2      c
# 3      l
# 4    NaN
# 5      e
# 6    NaN
# dtype: object

# %% [markdown]
# ## La gestion des `NaN` et `None`

# %%
s = pd.Series([1, 2])
s
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
s[0] = np.nan
s
# Out:
# 0    NaN
# 1    2.0
# dtype: float64

# %%
s = pd.Series([1, 2])
s
# Out:
# 0    1
# 1    2
# dtype: int64

# %%
s[0] = None
s
# Out:
# 0    NaN
# 1    2.0
# dtype: float64

# %%
s.isna()
# Out:
# 0     True
# 1    False
# dtype: bool

# %%
s.isnull()
# Out:
# 0     True
# 1    False
# dtype: bool

# %%
s.notna()
# Out:
# 0    False
# 1     True
# dtype: bool

# %%
s.notnull()
# Out:
# 0    False
# 1     True
# dtype: bool

# %%
s.dropna()
# Out:
# 1    2.0
# dtype: float64

# %%
s.fillna(0)
# Out:
# 0    0.0
# 1    2.0
# dtype: float64

# %%
names = ['alice', 'bob', 'charles']

bananas = pd.Series([6, 1], index=names[:-1])
apples = pd.Series([8, 5], index=names[1:])

fruits_feb = pd.DataFrame({'bananas': bananas, 'apples': apples})

print(fruits_feb)
# Out:
#          bananas  apples
# alice        6.0     NaN
# bob          1.0     8.0
# charles      NaN     5.0

# %%
fruits_feb.isna()
# Out:
#          bananas  apples
# alice      False    True
# bob        False   False
# charles     True   False

# %%
fruits_feb.notna()
# Out:
#          bananas  apples
# alice       True   False
# bob         True    True
# charles    False    True

# %%
p = pd.DataFrame([
    [1, 2, np.nan], 
    [3, np.nan, np.nan], 
    [7, 5, np.nan]
])

p
# Out:
#    0    1   2
# 0  1  2.0 NaN
# 1  3  NaN NaN
# 2  7  5.0 NaN

# %%
p.dropna()
# Out:
# Empty DataFrame
# Columns: [0, 1, 2]
# Index: []

# %%
p.dropna(axis=1)
# Out:
#    0
# 0  1
# 1  3
# 2  7

# %%
p.dropna(axis=1, how='all')
# Out:
#    0    1
# 0  1  2.0
# 1  3  NaN
# 2  7  5.0

# %%
p.dropna(thresh=2)
# Out:
#    0    1   2
# 0  1  2.0 NaN
# 2  7  5.0 NaN

# %%
print(p)
# Out:
#    0    1   2
# 0  1  2.0 NaN
# 1  3  NaN NaN
# 2  7  5.0 NaN

# %%
p.fillna(-1)
# Out:
#    0    1    2
# 0  1  2.0 -1.0
# 1  3 -1.0 -1.0
# 2  7  5.0 -1.0

# %%
p.fillna(method='bfill')
# Out:
# /var/folders/8s/q4htv1115d70bm1_gqh1mswc0000gn/T/ipykernel_8753/2672879933.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   p.fillna(method='bfill')
#    0    1   2
# 0  1  2.0 NaN
# 1  3  5.0 NaN
# 2  7  5.0 NaN

# %%
p.fillna(method='ffill', axis=1)
# Out:
# /var/folders/8s/q4htv1115d70bm1_gqh1mswc0000gn/T/ipykernel_8753/2184691565.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   p.fillna(method='ffill', axis=1)
#      0    1    2
# 0  1.0  2.0  2.0
# 1  3.0  3.0  3.0
# 2  7.0  5.0  5.0

# %%
# !p.dropna?

# %%
# !p.fillna?

# %% [markdown]
# ## Les MultiIndex

# %% [markdown]
# `pandas` avait historiquement d'autres structures de données en plus des `Series` et des `DataFrame` permettant d'exprimer des dimensionnalités supérieures à 2, comme par exemple les `Panel`. Mais pour des raisons de maintenance du code et d'optimisation, les développeurs ont décidé de ne garder que les `Series` et les `DataFrame`. Alors, comment exprimer des données avec plus de deux dimensions ?
#
# On utilise pour cela des `MultiIndex`. Un `MultiIndex` est un index qui peut être utilisé partout où l'on utilise un index (dans une `Series`, ou comme ligne ou colonne d'une `DataFrame`) et qui a pour caractéristique d'avoir plusieurs niveaux.
#
# Comme tous types d'index, et parce qu'un `MultiIndex` est une sous classe d'`Index`, pandas va correctement aligner les `Series` et les `DataFrame` avec des `MultiIndex`.

# %%
names = ['alice', 'bob', 'sonia']

age = pd.Series([12, 13, 16], index=names)
height = pd.Series([130, 140, 165], index=names)
sex = pd.Series(list('fmf'), index=names)

p = pd.DataFrame({'age': age, 'height': height, 'sex': sex})
print(p)
# Out:
#        age  height sex
# alice   12     130   f
# bob     13     140   m
# sonia   16     165   f

# %% [markdown]
# - Passage d'une DataFrame à une Séries avec un MultiIndex

# %%
s_multiIndex = p.unstack()
print(s_multiIndex)
# Out:
# age     alice     12
#         bob       13
#         sonia     16
# height  alice    130
#         bob      140
#         sonia    165
# sex     alice      f
#         bob        m
#         sonia      f
# dtype: object

# %%
s_multiIndex.index
# Out:
# MultiIndex([(   'age', 'alice'),
#             (   'age',   'bob'),
#             (   'age', 'sonia'),
#             ('height', 'alice'),
#             ('height',   'bob'),
#             ('height', 'sonia'),
#             (   'sex', 'alice'),
#             (   'sex',   'bob'),
#             (   'sex', 'sonia')],
#            )

# %%
print(s_multiIndex.values)
# Out:
# [12 13 16 130 140 165 'f' 'm' 'f']

# %%
print(s_multiIndex.keys())
# Out:
# MultiIndex([(   'age', 'alice'),
#             (   'age',   'bob'),
#             (   'age', 'sonia'),
#             ('height', 'alice'),
#             ('height',   'bob'),
#             ('height', 'sonia'),
#             (   'sex', 'alice'),
#             (   'sex',   'bob'),
#             (   'sex', 'sonia')],
#            )

# %% [markdown]
# ### Créer un MultiIndex

# %%
names = ['alice', 'alice', 'alice', 'bob', 'bob', 'bob']
age = [2014, 2015, 2016, 2014, 2015, 2016]

s_list = pd.Series(
    [40, 42, 45, 38, 40, 40],
    index=[names, age]
)

print(s_list)
# Out:
# alice  2014    40
#        2015    42
#        2016    45
# bob    2014    38
#        2015    40
#        2016    40
# dtype: int64

# %% [markdown]
# - Ou

# %%
s_tuple = pd.Series({
    ('alice', 2014): 40,
    ('alice', 2015): 42,
    ('alice', 2016): 45,
    ('bob', 2014): 38,
    ('bob', 2015): 40,
    ('bob', 2016): 40
})

print(s_tuple)
# Out:
# alice  2014    40
#        2015    42
#        2016    45
# bob    2014    38
#        2015    40
#        2016    40
# dtype: int64

# %% [markdown]
# - avec `from_product()`

# %%
name = ['alice', 'bob']
year = [2014, 2015, 2016]

i = pd.MultiIndex.from_product([name, year])
s = pd.Series([40, 42, 45, 38, 40,40], index=i)

print(s)
# Out:
# alice  2014    40
#        2015    42
#        2016    45
# bob    2014    38
#        2015    40
#        2016    40
# dtype: int64

# %% [markdown]
# - Nommer les niveaux d'un MultiIndex

# %%
name = ['alice', 'bob']
year = [2014, 2015, 2016]

i = pd.MultiIndex.from_product([name, year], names=['name', 'year'])
s = pd.Series([40, 42, 45, 38, 40,40], index=i)

print(s)
# Out:
# name   year
# alice  2014    40
#        2015    42
#        2016    45
# bob    2014    38
#        2015    40
#        2016    40
# dtype: int64

# %%
s.index.names = ['NAMES', 'YEARS']
print(s)
# Out:
# NAMES  YEARS
# alice  2014     40
#        2015     42
#        2016     45
# bob    2014     38
#        2015     40
#        2016     40
# dtype: int64

# %%
index = pd.MultiIndex.from_product([[2013, 2014],
                                    [1, 2, 3]],
                                   names=['year',
                                          'visit'])

columns = pd.MultiIndex.from_product([['Bob', 'Sue'],
                                      ['avant', 'arrière']],
                                     names=['client',
                                            'pression'])

# on crée des pressions de pneus factices
data = 2 + np.random.rand(6, 4)

# on crée la DataFrame
mecanics_data = pd.DataFrame(data, index=index, columns=columns)
print(mecanics_data)
# Out:
# client           Bob                 Sue
# pression       avant   arrière     avant   arrière
# year visit
# 2013 1      2.011461  2.093788  2.883125  2.760708
#      2      2.980404  2.672687  2.963015  2.608135
#      3      2.995602  2.895636  2.824853  2.081218
# 2014 1      2.094435  2.530183  2.701821  2.834399
#      2      2.764014  2.727816  2.887168  2.037819
#      3      2.735705  2.213077  2.907461  2.612150

# %%
mecanics_data.loc[2013, 'Bob']
# Out:
# pression     avant   arrière
# visit
# 1         2.011461  2.093788
# 2         2.980404  2.672687
# 3         2.995602  2.895636

# %%
mecanics_data.loc[(2013, 2), ('Bob', 'avant')]
# Out:
# np.float64(2.980404478189391)

# %%
# slice(None) signifie tous les éléments du niveau
print(mecanics_data.loc[slice((2013, 2), (2014, 1)), ('Sue', slice(None))])
# Out:
# client           Sue
# pression       avant   arrière
# year visit
# 2013 2      2.963015  2.608135
#      3      2.824853  2.081218
# 2014 1      2.701821  2.834399

# %%
# on peut utiliser la notation : si on ne distingue par les niveaux
print(mecanics_data.loc[(slice(None), slice(1, 2)), :])
# Out:
# client           Bob                 Sue
# pression       avant   arrière     avant   arrière
# year visit
# 2013 1      2.011461  2.093788  2.883125  2.760708
#      2      2.980404  2.672687  2.963015  2.608135
# 2014 1      2.094435  2.530183  2.701821  2.834399
#      2      2.764014  2.727816  2.887168  2.037819

# %%
# on peut aussi utiliser pd.IndexSlice pour slicer avec une notation
# un peu plus concise
idx = pd.IndexSlice
print(idx, '\n')
print(mecanics_data.loc[idx[:, 1:2], idx['Sue', :]])
# Out:
# <pandas.core.indexing._IndexSlice object at 0x10fa2d010>
#
# client           Sue
# pression       avant   arrière
# year visit
# 2013 1      2.883125  2.760708
#      2      2.963015  2.608135
# 2014 1      2.701821  2.834399
#      2      2.887168  2.037819

# %%
idx
