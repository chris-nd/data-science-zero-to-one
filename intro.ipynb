# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
L = list(range(1000))

# %% [markdown]
# ## 1 - Bibliothèque Numpy

# %% [markdown]
# C'est la librairie de référence pour gérer et manipuler des tableaux multi-dimensionnels en python

# %%
a = np.array(L)

# %%
# %timeit [x**2 for x in L]
# Out:
# 182 μs ± 89.9 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit [x**2 for x in a]
# Out:
# 201 μs ± 31.4 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %timeit a**2
# Out:
# 1.75 μs ± 469 ns per loop (mean ± std. dev. of 7 runs, 100,000 loops each)

# %% [markdown]
# ## 2 - Bibliothèque Pandas

# %% [markdown]
# C'est la librairie de référence qui permet d'ajouter des alias à des tableaux Numpy, ce qui sert à donner des labels aux lignes et aux colonnes des tableaux, afin de pouvoir accéder de manière plus intuitive et expréssive aux éléments de ce tableau

# %%
tit = sns.load_dataset('titanic')

# %%
tit.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
t = tit.pivot_table('survived',
                    aggfunc= np.mean,
                    index='class',
                    columns='sex' )
# Out:
# /var/folders/8s/q4htv1115d70bm1_gqh1mswc0000gn/T/ipykernel_3737/3775720136.py:1: FutureWarning: The default value of observed=False is deprecated and will change to observed=True in a future version of pandas. Specify observed=False to silence this warning and retain the current behavior
#   t = tit.pivot_table('survived',
# /var/folders/8s/q4htv1115d70bm1_gqh1mswc0000gn/T/ipykernel_3737/3775720136.py:1: FutureWarning: The provided callable <function mean at 0x105ebaf00> is currently using DataFrameGroupBy.mean. In a future version of pandas, the provided callable will be used directly. To keep current behavior pass the string "mean" instead.
#   t = tit.pivot_table('survived',

# %%
t
# Out:
# sex       female      male
# class
# First   0.968085  0.368852
# Second  0.921053  0.157407
# Third   0.500000  0.135447

# %%
t.plot(kind='bar')
# Out:
# <Axes: xlabel='class'>
